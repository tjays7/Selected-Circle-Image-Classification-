# %%
# Total images: 13,115

# 2865 labelled a
# 2506 labelled b
# 2196 labelled c
# 2065 labelled d
# 3482 labelled e

# %%
import cv2
import os
import matplotlib.pyplot as plt
from tqdm import tqdm
import random
import numpy as np

# %%
path = os.path.abspath('DS1')

for img_file in os.listdir(path):  
            
        img = cv2.imread(os.path.join(path,img_file),0)
        cv2.imshow("image",img)
        cv2.waitKey(0)
        cv2.destroyAllWindows()
        break  # because we want single image

# %%
print(img.shape)
IMG_SIZE_y = 22
IMG_SIZE_x = 90
# Out:
# (22, 90)

# %%
for img_file in tqdm(os.listdir(path)):  
    img = cv2.imread(os.path.join(path,img_file),0)
    #img_resize = cv2.resize(img, (IMG_SIZE_x, IMG_SIZE_y))
    #cv2.imwrite(os.path.join(path,img_file),img_resize)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 13114/13114 [00:34<00:00, 380.83it/s]

# %%
i=0
for img_file in os.listdir(path):  
    img = cv2.imread(os.path.join(path,img_file),0)
    print(img.shape)
    i+=1
    if i>10:
        break
# Out:
# (22, 90)
# (22, 90)
# (22, 90)
# (22, 90)
# (22, 90)
# (22, 90)
# (22, 90)
# (22, 90)
# (22, 90)
# (22, 90)
# (22, 90)

# %%
labels = [0,1,2,3,4]

training_data =[]

training_data = [[cv2.imread(os.path.join(path,img_file) ,0) ,labels[0]] if os.path.splitext(img_file)[0].endswith('a') 
                  else ([cv2.imread(os.path.join(path,img_file) ,0),labels[1]]) if os.path.splitext(img_file)[0].endswith('b')
                 else ([cv2.imread(os.path.join(path,img_file) ,0),labels[2]]) if os.path.splitext(img_file)[0].endswith('c')
                 else ([cv2.imread(os.path.join(path,img_file) ,0),labels[3]]) if os.path.splitext(img_file)[0].endswith('d')
                 else ([cv2.imread(os.path.join(path,img_file) ,0),labels[4]]) if os.path.splitext(img_file)[0].endswith('e')
                 else ''
                 for img_file in tqdm(os.listdir(path))]

print(training_data)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 13114/13114 [00:02<00:00, 5536.89it/s]
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
len(training_data)
# Out:
# 13114

# %%
len(training_data[0])
# Out:
# 2

# %%
training_data[0]
# Out:
# [array([[ 48,  55, 139, ..., 128, 115,  37],
#         [ 73,  77, 172, ..., 149, 139,  42],
#         [ 93,  98, 210, ..., 215, 193,  68],
#         ...,
#         [ 80, 103, 226, ..., 235, 212,  63],
#         [ 97, 110, 216, ..., 228, 195,  69],
#         [ 75,  78, 169, ..., 180, 169,  62]], dtype=uint8), 2]

# %%
random.shuffle(training_data)

# %%
for sample in training_data[:10]:
    print(sample[1])
# Out:
# 4
# 4
# 4
# 2
# 1
# 2
# 3
# 1
# 0
# 2

# %%
X = []
y = []

for features,label in training_data:
    X.append(features)
    y.append(label)

# %%
print(len(X))
print(X)
# Out:
# 13114
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
print(len(y))
print(y)
# Out:
# 13114
# ...

# %%
X = np.array(X).reshape(-1,IMG_SIZE_x, IMG_SIZE_y,1) # -1 is all the features, shape of array would be IMG_SIZE x IMG_SIZE, 
# and 1 means number of channels
# in tensorflow, we have to represent images as (samples, height, width, channels)

# %%
X
# Out:
# array([[[[161],
#          [155],
#          [216],
#          ...,
#          [222],
#          [226],
#          [222]],
#
#         [[221],
#          [218],
#          [220],
#          ...,
#          [221],
#          [223],
#          [223]],
#
#         [[218],
#          [217],
#          [220],
#          ...,
#          [217],
#          [217],
#          [217]],
#
#         ...,
#
#         [[204],
#          [201],
#          [201],
#          ...,
#          [197],
#          [197],
#          [198]],
#
#         [[195],
#          [192],
#          [189],
#          ...,
#          [194],
#          [194],
#          [197]],
#
#         [[200],
#          [199],
#          [196],
#          ...,
#          [197],
#          [189],
#          [136]]],
#
#
#        [[[203],
#          [136],
#          [222],
#          ...,
#          [253],
#          [248],
#          [246]],
#
#         [[249],
#          [254],
#          [253],
#          ...,
#          [250],
# ...

# %%
X[0].shape
# Out:
# (90, 22, 1)

# %%
import pickle

pickle_out = open("X.pickle","wb")
pickle.dump(X, pickle_out)
pickle_out.close()

pickle_out = open("y.pickle","wb")
pickle.dump(y, pickle_out)
pickle_out.close()

# %%
X[0]
# Out:
# array([[[ 96],
#         [ 66],
#         [120],
#         ...,
#         [114],
#         [109],
#         [103]],
#
#        [[100],
#         [100],
#         [105],
#         ...,
#         [122],
#         [118],
#         [117]],
#
#        [[119],
#         [120],
#         [122],
#         ...,
#         [116],
#         [113],
#         [120]],
#
#        ...,
#
#        [[119],
#         [121],
#         [120],
#         ...,
#         [109],
#         [113],
#         [117]],
#
#        [[117],
#         [116],
#         [116],
#         ...,
#         [112],
#         [109],
#         [107]],
#
#        [[107],
#         [108],
#         [111],
#         ...,
#         [116],
#         [113],
#         [ 85]]], dtype=uint8)
